# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib


from astropy.io import fits
import os


from gPhoton import gFind
from gPhoton import gAperture
from gPhoton import gMap
from gPhoton.gphoton_utils import read_lc
import datetime

matplotlib.rcParams.update({'font.size':18})
matplotlib.rcParams.update({'font.family':'serif'})

# %%
file = 'III_159A_catalog.dat'
names = ('Star', 'Nobs', 'Smin', 'Smax', 'Smean', 'e_Smean', 'sdS', 'Wmin', 'Wmean', 
         'Date1', 'Date2', 'SName', 'RAdeg DEdeg', 's', 'Bmag', 'Vmag', 'ASCC', 'HIP')
hk = pd.read_table(file, delimiter='|', comment='#', names=names)

radec = hk['RAdeg DEdeg'].str.split(' ', expand=True).loc[:,0:1]
radec.columns = ['RA', 'Dec']
print(radec)
# Out:
#             RA       Dec
# 0     144.2052  +57.9121
# 1     176.6498  +50.8832
# 2     166.3839  +43.5245
# 3     061.5470  +32.9529
# 4     025.4714  +02.7044
# 5     025.4714  +02.7044
# 6     072.7322  +00.5766
# 7     184.6508  +23.1201
# 8     184.7562  +24.8462
# 9     184.8682  +24.2843
# 10    185.1899  +25.7659
# 11    185.4543  +26.5491
# 12    185.4840  +27.3095
# 13    185.6032  +22.4642
# 14    185.6308  +25.8285
# 15    185.7850  +25.8514
# 16    185.9243  +26.6015
# 17    186.2594  +25.5607
# 18    186.3438  +23.2291
# 19    186.4665  +26.7767
# 20    186.7761  +26.8457
# 21    187.4205  +24.5208
# 22    263.8923  +61.6828
# 23    271.3632  +02.5020
# 24    049.3595  +07.6558
# 25    049.3595  +07.6558
# 26    049.3862  +07.6902
# 27    049.3862  +07.6902
# 28    052.6264  +20.1034
# 29    053.2082  +23.6923
# ...        ...       ...
# 3081  274.0091  +13.9146
# 3082  287.2250  +34.0621
# 3083  287.2250  +34.0621
# 3084  293.1575  +00.5775
# 3085  293.1575  +00.5775
# 3086  295.8551  +10.0893
# 3087  307.8832  +33.7758
# 3088  307.8832  +33.7758
# 3089  321.6770  +03.7373
# 3090  326.1250  +41.5974
# 3091  329.5999  +75.5890
# 3092  329.5999  +75.5890
# 3093  333.0277  +31.5624
# 3094  333.0277  +31.5624
# 3095  336.1902  +22.5513
# 3096  336.6551  +04.3936
# 3097  341.8061  +18.3843
# 3098  342.9716  +31.7543
# 3099  342.9716  +31.7543
# 3100  357.3699  +35.6644
# 3101  357.6154  +30.3532
# 3102  357.6154  +30.3532
# 3103
# 3104
# 3105
# 3106
# 3107
# 3108
# 3109
# 3110
#
# [3111 rows x 2 columns]

# %%
# i = 281 # the star w/ 77 visits in GALEX (HD 4174, symbiotic M giant)

i = 261 # 74 visits (HD 3765)

# %%
# target = hk['Star'][i]
# ra = float(radec['RA'][i][1:])
# print(ra)
# dec = float(radec['Dec'][i][1:])
# print(dec)

# coordinates found for HD 4174
# 11.1549167,  40.6793889 from isrc.


# coordinates that I found
# ra = 10.2920
# dec = 40.2025


# found using isrc data, extremely close to what I found
# ra = 10.20528789
# dec = 40.18717517

# new coordinates with procession calculated
ra = 10.25784158
dec = 40.20826933

step_size = 10. # the time resolution
img_step_size = 30.
img_size = [0.1, 0.1]
phot_rad = 0.0045
# phot_rad = 0.01
ap_in = 0.0060 #changed from .005
ap_out = 0.0070 #changed from .006
# ap_in = 0.015
# ap_out = 0.02



# img_step_size = 30.
#screen saver

print(target)
# Out:
# HD   4174

# %%
exp_data = gFind(band="NUV", skypos=[ra, dec], exponly=True)
k = 0;
timeArray = []
for tstart, tstop in zip(exp_data['NUV']['t0'], exp_data['NUV']['t1']):
        
        timeArray.append((tstart, tstop))
#         print(tstart, tstop, tstop-tstart)
        print(timeArray[k][0],timeArray[k][1],timeArray[k][1]-timeArray[k][0])
        k = k + 1
#         print(len(timeArray))
#         if k == 5:
#             break
# Out:
# NUV: 114113.0s (raw) in 74 exposures.
# 749646829.995 749647397.995 568.0
# 749651677.995 749653315.995 1638.0
# 750580904.995 750582295.995 1391.0
# 873882164.995 873883767.995 1603.0
# 874213366.995 874214202.995 836.0
# 874231111.995 874232816.995 1705.0
# 874728017.995 874728517.995 500.0
# 903965462.995 903966910.995 1448.0
# 903971379.995 903972827.995 1448.0
# 905592230.995 905593787.995 1557.0
# 905609883.995 905611532.995 1649.0
# 908934612.995 908936285.995 1673.0
# 908993735.995 908995437.995 1702.0
# 934810539.995 934811921.995 1382.0
# 934899261.995 934900698.995 1437.0
# 934988026.995 934989471.995 1445.0
# 935071049.995 935072321.995 1272.0
# 935165455.995 935167000.995 1545.0
# 935248261.995 935249836.995 1575.0
# 935337002.995 935338583.995 1581.0
# 935413860.995 935415492.995 1632.0
# 935508511.995 935510141.995 1630.0
# 935591282.995 935592956.995 1674.0
# 935680017.995 935681679.995 1662.0
# 935762789.995 935764486.995 1697.0
# 935863355.995 935865033.995 1678.0
# 935934301.995 935936007.995 1706.0
# 936028962.995 936030636.995 1674.0
# 936111739.995 936113439.995 1700.0
# 938513440.995 938515110.995 1670.0
# 938602202.995 938603835.995 1633.0
# 938685001.995 938686650.995 1649.0
# 938767827.995 938769467.995 1640.0
# 938850655.995 938852289.995 1634.0
# 938939424.995 938941027.995 1603.0
# 939051808.995 939053434.995 1626.0
# 939140573.995 939142177.995 1604.0
# 939223372.995 939225006.995 1634.0
# 939306216.995 939307832.995 1616.0
# 939389033.995 939390659.995 1626.0
# 939477761.995 939479397.995 1636.0
# 939560545.995 939562218.995 1673.0
# 939726157.995 939727849.995 1692.0
# 939814876.995 939816574.995 1698.0
# 939897678.995 939899382.995 1704.0
# 939980505.995 939982184.995 1679.0
# 940098769.995 940100413.995 1644.0
# 940181573.995 940183268.995 1695.0
# 942317389.995 942319037.995 1648.0
# 942406125.995 942407765.995 1640.0
# 942488898.995 942490577.995 1679.0
# 942583550.995 942585215.995 1665.0
# 942660410.995 942662108.995 1698.0
# 942755041.995 942756743.995 1702.0
# 942837844.995 942839549.995 1705.0
# 942920678.995 942922354.995 1676.0
# 965695500.995 965696888.995 1388.0
# 965760572.995 965761991.995 1419.0
# 965867069.995 965868514.995 1445.0
# 965932105.995 965933607.995 1502.0
# 966038586.995 966040111.995 1525.0
# 966103615.995 966105192.995 1577.0
# 966210062.995 966211677.995 1615.0
# 966275112.995 966276748.995 1636.0
# 966381567.995 966383218.995 1651.0
# 966446605.995 966448280.995 1675.0
# 996666824.995 996668265.995 1441.0
# 996761446.995 996762936.995 1490.0
# 996838320.995 996839850.995 1530.0
# 996932956.995 996934502.995 1546.0
# 997015812.995 997017317.995 1505.0
# 997110323.995 997111953.995 1630.0
# 997187185.995 997188841.995 1656.0
# 1004757879.0 1004757984.0 105.0

# %%
(exp_data['NUV']['t0'] - exp_data['NUV']['t0'][0]) / (60.*60.*24.*365.)
# Out:
# array([  0.00000000e+00,   1.53729072e-04,   2.96193239e-02,
#          3.93947663e+00,   3.94997898e+00,   3.95054167e+00,
#          3.96629845e+00,   4.89341175e+00,   4.89359938e+00,
#          4.94499623e+00,   4.94555600e+00,   5.05098246e+00,
#          5.05285724e+00,   5.87150273e+00,   5.87431608e+00,
#          5.87713080e+00,   5.87976344e+00,   5.88275704e+00,
#          5.88538280e+00,   5.88819676e+00,   5.89063391e+00,
#          5.89363527e+00,   5.89625993e+00,   5.89907369e+00,
#          5.90169838e+00,   5.90488730e+00,   5.90713699e+00,
#          5.91013867e+00,   5.91276351e+00,   5.98892095e+00,
#          5.99173557e+00,   5.99436111e+00,   5.99698751e+00,
#          5.99961396e+00,   6.00242881e+00,   6.00599248e+00,
#          6.00880720e+00,   6.01143274e+00,   6.01405971e+00,
#          6.01668582e+00,   6.01949937e+00,   6.02212443e+00,
#          6.02737595e+00,   6.03018921e+00,   6.03281485e+00,
#          6.03544127e+00,   6.03919140e+00,   6.04181710e+00,
#          6.10954338e+00,   6.11235718e+00,   6.11498189e+00,
#          6.11798329e+00,   6.12042050e+00,   6.12342123e+00,
#          6.12604690e+00,   6.12867355e+00,   6.85085842e+00,
#          6.85292184e+00,   6.85629883e+00,   6.85836111e+00,
#          6.86173760e+00,   6.86379966e+00,   6.86717507e+00,
#          6.86923779e+00,   6.87261346e+00,   6.87467580e+00,
#          7.83295266e+00,   7.83595310e+00,   7.83839076e+00,
#          7.84139165e+00,   7.84401899e+00,   7.84701592e+00,
#          7.84945320e+00,   8.08951830e+00])

# %%
step_size = 100 # seconds

flux = np.zeros(len(exp_data['NUV']['t0']))

aVar = True
counter = 0

currentTime = str(datetime.datetime.now())
currentTime = currentTime.split(" ")
currentTime = currentTime[1].split(":")
currentTime = str(currentTime[0])+":"+str(currentTime[1])

currentDate = str(datetime.date.today()) + "_" + str(counter)
while(aVar):
    if not os.path.exists(currentDate):
        os.makedirs(currentDate)
        os.makedirs(currentDate + "/ds9_Images")
        os.makedirs(currentDate + "/data")
        aVar = False
    else:
        counter = counter + 1 
        currentDate = str(datetime.date.today()) + "_" + str(counter)
        avar = True

print(datetime.datetime.now())
for k in range(len(exp_data['NUV']['t0'])):
    photon_events = gAperture(band='NUV', skypos=[ra, dec], stepsz=step_size, radius= phot_rad,
                              annulus=[ap_in, ap_out], verbose=3, csvfile=currentDate+"/data/"+target+ '_' +str(k)+"_lc.csv",
                              trange=[int(exp_data['NUV']['t0'][k]), int(exp_data['NUV']['t1'][k])+1], 
                              overwrite=True)
    data = read_lc(currentDate+'/data/'+target+ '_' +str(k)+"_lc.csv")
    flux[k] = np.median(data['flux_bgsub'])
    print(datetime.datetime.now(), k)
# Out:
# 2017-05-04 16:06:50.789275
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [749646829, 749647398]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _0_lc.csv
#  verbose: 3
# 2017-05-04 16:07:27.859546 0                                20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [749651677, 749653316]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _1_lc.csv
#  verbose: 3
# 2017-05-04 16:09:57.394947 1                                20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [750580904, 750582296]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _2_lc.csv
#  verbose: 3
# 2017-05-04 16:11:30.801462 2                                20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [873882164, 873883768]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _3_lc.csv
#  verbose: 3
# 2017-05-04 16:14:39.516167 3                                20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [874213366, 874214203]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _4_lc.csv
#  verbose: 3
# 2017-05-04 16:15:31.417235 4                                20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [874231111, 874232817]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _5_lc.csv
#  verbose: 3
# 2017-05-04 16:17:09.399042 5                                20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [874728017, 874728518]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _6_lc.csv
#  verbose: 3
# 2017-05-04 16:17:41.568254 6                                20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [903965462, 903966911]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _7_lc.csv
#  verbose: 3
# 2017-05-04 16:19:04.628289 7                                20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [903971379, 903972828]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _8_lc.csv
#  verbose: 3
# 2017-05-04 16:21:55.120963 8                                20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [905592230, 905593788]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _9_lc.csv
#  verbose: 3
# 2017-05-04 16:23:34.754753 9                                20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [905609883, 905611533]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _10_lc.csv
#  verbose: 3
# 2017-05-04 16:26:40.650948 10                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [908934612, 908936286]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _11_lc.csv
#  verbose: 3
# 2017-05-04 16:29:48.982380 11                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [908993735, 908995438]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _12_lc.csv
#  verbose: 3
# 2017-05-04 16:31:27.023607 12                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [934810539, 934811922]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _13_lc.csv
#  verbose: 3
# 2017-05-04 16:34:28.291650 13                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [934899261, 934900699]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _14_lc.csv
#  verbose: 3
# 2017-05-04 16:36:02.842479 14                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [934988026, 934989472]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _15_lc.csv
#  verbose: 3
# 2017-05-04 16:39:04.816259 15                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [935071049, 935072322]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _16_lc.csv
#  verbose: 3
# 2017-05-04 16:40:23.727488 16                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [935165455, 935167001]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _17_lc.csv
#  verbose: 3
# 2017-05-04 16:42:50.775771 17                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [935248261, 935249837]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _18_lc.csv
#  verbose: 3
# 2017-05-04 16:44:32.789253 18                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [935337002, 935338584]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _19_lc.csv
#  verbose: 3
# 2017-05-04 16:47:39.841708 19                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [935413860, 935415493]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _20_lc.csv
#  verbose: 3
# 2017-05-04 16:49:09.803658 20                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [935508511, 935510142]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _21_lc.csv
#  verbose: 3
# 2017-05-04 16:52:05.211265 21                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [935591282, 935592957]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _22_lc.csv
#  verbose: 3
# 2017-05-04 16:53:45.144418 22                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [935680017, 935681680]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _23_lc.csv
#  verbose: 3
# 2017-05-04 16:56:35.747808 23                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [935762789, 935764487]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _24_lc.csv
#  verbose: 3
# 2017-05-04 17:00:07.294438 24                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [935863355, 935865034]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _25_lc.csv
#  verbose: 3
# 2017-05-04 17:03:43.862629 25                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [935934301, 935936008]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _26_lc.csv
#  verbose: 3
# 2017-05-04 17:05:31.146439 26                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [936028962, 936030637]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _27_lc.csv
#  verbose: 3
# 2017-05-04 17:08:42.864065 27                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [936111739, 936113440]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _28_lc.csv
#  verbose: 3
# 2017-05-04 17:10:20.990503 28                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [938513440, 938515111]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _29_lc.csv
#  verbose: 3
# 2017-05-04 17:12:12.490049 29                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [938602202, 938603836]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _30_lc.csv
#  verbose: 3
# 2017-05-04 17:15:47.786080 30                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [938685001, 938686651]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _31_lc.csv
#  verbose: 3
# 2017-05-04 17:17:23.452889 31                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [938767827, 938769468]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _32_lc.csv
#  verbose: 3
# 2017-05-04 17:21:11.715619 32                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [938850655, 938852290]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _33_lc.csv
#  verbose: 3
# 2017-05-04 17:22:49.332824 33                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [938939424, 938941028]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _34_lc.csv
#  verbose: 3
# 2017-05-04 17:25:42.873322 34                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [939051808, 939053435]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _35_lc.csv
#  verbose: 3
# 2017-05-04 17:27:24.511694 35                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [939140573, 939142178]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _36_lc.csv
#  verbose: 3
# 2017-05-04 17:30:06.569769 36                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [939223372, 939225007]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _37_lc.csv
#  verbose: 3
# 2017-05-04 17:31:42.315292 37                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [939306216, 939307833]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _38_lc.csv
#  verbose: 3
# 2017-05-04 17:34:36.012228 38                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [939389033, 939390660]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _39_lc.csv
#  verbose: 3
# 2017-05-04 17:36:22.400453 39                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [939477761, 939479398]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _40_lc.csv
#  verbose: 3
# 2017-05-04 17:39:20.401535 40                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [939560545, 939562219]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _41_lc.csv
#  verbose: 3
# 2017-05-04 17:41:02.091323 41                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [939726157, 939727850]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _42_lc.csv
#  verbose: 3
# 2017-05-04 17:42:43.653088 42                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [939814876, 939816575]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _43_lc.csv
#  verbose: 3
# 2017-05-04 17:45:48.104326 43                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [939897678, 939899383]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _44_lc.csv
#  verbose: 3
# 2017-05-04 17:47:36.270079 44                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [939980505, 939982185]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _45_lc.csv
#  verbose: 3
# 2017-05-04 17:50:27.104794 45                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [940098769, 940100414]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _46_lc.csv
#  verbose: 3
# 2017-05-04 17:52:02.665686 46                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [940181573, 940183269]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _47_lc.csv
#  verbose: 3
# 2017-05-04 17:54:49.336705 47                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [942317389, 942319038]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _48_lc.csv
#  verbose: 3
# 2017-05-04 17:56:38.263555 48                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [942406125, 942407766]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _49_lc.csv
#  verbose: 3
# 2017-05-04 17:59:30.665535 49                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [942488898, 942490578]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _50_lc.csv
#  verbose: 3
# 2017-05-04 18:01:18.377773 50                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [942583550, 942585216]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _51_lc.csv
#  verbose: 3
# 2017-05-04 18:04:38.105028 51                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [942660410, 942662109]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _52_lc.csv
#  verbose: 3
# 2017-05-04 18:06:24.333931 52                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [942755041, 942756744]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _53_lc.csv
#  verbose: 3
# 2017-05-04 18:09:36.299910 53                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [942837844, 942839550]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _54_lc.csv
#  verbose: 3
# 2017-05-04 18:11:15.701911 54                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [942920678, 942922355]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _55_lc.csv
#  verbose: 3
# 2017-05-04 18:13:49.424732 55                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [965695500, 965696889]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _56_lc.csv
#  verbose: 3
# 2017-05-04 18:16:36.222128 56                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [965760572, 965761992]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _57_lc.csv
#  verbose: 3
# 2017-05-04 18:20:10.640977 57                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [965867069, 965868515]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _58_lc.csv
#  verbose: 3
# 2017-05-04 18:22:57.151478 58                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [965932105, 965933608]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _59_lc.csv
#  verbose: 3
# 2017-05-04 18:24:29.409516 59                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [966038586, 966040112]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _60_lc.csv
#  verbose: 3
# 2017-05-04 18:28:12.911680 60                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [966103615, 966105193]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _61_lc.csv
#  verbose: 3
# 2017-05-04 18:29:45.129926 61                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [966210062, 966211678]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _62_lc.csv
#  verbose: 3
# 2017-05-04 18:32:23.972781 62                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [966275112, 966276749]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _63_lc.csv
#  verbose: 3
# 2017-05-04 18:34:04.097765 63                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [966381567, 966383219]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _64_lc.csv
#  verbose: 3
# 2017-05-04 18:36:55.649463 64                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [966446605, 966448281]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _65_lc.csv
#  verbose: 3
# 2017-05-04 18:38:30.721352 65                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [996666824, 996668266]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _66_lc.csv
#  verbose: 3
# 2017-05-04 18:40:11.223431 66                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [996761446, 996762937]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _67_lc.csv
#  verbose: 3
# 2017-05-04 18:43:27.030659 67                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [996838320, 996839851]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _68_lc.csv
#  verbose: 3
# 2017-05-04 18:44:56.416235 68                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [996932956, 996934503]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _69_lc.csv
#  verbose: 3
# 2017-05-04 18:47:56.208541 69                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [997015812, 997017318]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _70_lc.csv
#  verbose: 3
# 2017-05-04 18:49:37.899558 70                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [997110323, 997111954]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _71_lc.csv
#  verbose: 3
# 2017-05-04 18:52:37.043658 71                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [997187185, 997188842]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _72_lc.csv
#  verbose: 3
# 2017-05-04 18:54:15.342557 72                               20826933]
# Using v1.28.4 of gAperture.
# Generating a light curve with the following paramters:
#  band:    NUV
#  skypos:  [10.25784158, 40.20826933]
#  tranges: [1004757878, 1004757984]
#  radius:  0.0045
#  annulus: [0.006, 0.007]
#  stepsz:  100
#  csvfile: 2017-05-04_1/data/HD   4174 _73_lc.csv
#  verbose: 3
# 2017-05-04 18:54:32.734720 73                               20826933]

# %%
plt.figure(figsize=(9,5))
plt.scatter((exp_data['NUV']['t0'] - exp_data['NUV']['t0'][0]) / (60.*60.*24.*365.), flux/1e-14,
           s=50, alpha=0.5, lw=0, color='k')
plt.xlabel('Time (years)')
plt.ylabel('NUV Flux ($10^{-14}$)')
plt.title(target)

plt.savefig(currentDate+'/'+target+'_.png', dpi=150, bbox_inches='tight', pad_inches=0.25)
plt.savefig("Plots/"+currentDate+"_"+currentTime+"_"+target+'_.png', dpi=150, bbox_inches='tight', pad_inches=0.25)

# %%
#let's explore just around year 6, big scatter
plt.figure(figsize=(9,5))
plt.scatter((exp_data['NUV']['t0'] - exp_data['NUV']['t0'][0]) / (60.*60.*24.*365.), flux/1e-14,
           s=50, alpha=0.5, lw=0, color='k')
plt.xlabel('Time (years)')
plt.ylabel('NUV Flux ($10^{-14}$)')
plt.xlim(5.8,6.2)
plt.title(target)

# plt.savefig(target+'.png', dpi=150, bbox_inches='tight', pad_inches=0.25)

# %%
exp_data['NUV']['t0'][0]
# Out:
# 749646829.995

# %%
# lets see if the mean flux for each visit is available? (doubt it...)
# would eliminate need for gAperature step for quick-look evolution!
# exp_data2 = gFind(band="both", skypos=[ra, dec])

# %%
# exp_data2
# NOPE....

# %%
for k in range(0,len(timeArray)):  
    w = str(k)
    gMap(band= "NUV", skypos=[ra, dec], stepsz=100 , skyrange=[0.010, 0.010],
             cntfile= currentDate+"/ds9_Images/"+"HD_3765_visitNumber_"+w+".fits",
             trange=[timeArray[k][0], timeArray[k][1]])
#   values I found 10.2920hours, 40.2025degrees
#   test with 10.20528789,  40.18717517
#   old skypos=[10.3042, 40.1888]
#   gMap uses degrees for image size
#     if (k ==3):
#         break

# %%
gMap(band='NUV', skypos=[10.3042, 40.1888], skyrange=[0.033, 0.033], cntfile="helix_fuv.fits" )

# %%
exp_data['NUV']

# %%
gMap(band= "NUV", skypos=[10.3042, 40.1888], stepsz=100 , skyrange=[0.05, 0.05],
             cntfile= "gj_3765test93_count_movie.fits", trange=[749646829, 749647398])
